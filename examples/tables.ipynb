# %%
import numpy as np
# from mcdalp.core.visualize.table import CrispTable
from mcdalp.core.credibility import CredibilityMatrix
from mcdalp.core.score import Score
from mcdalp.outranking.crisp import CrispOutranking

# %%
simple2 = np.array([[1,1,0],[0,1,0],[0,0,0]], dtype=np.int32)
l_simple2 = ["A", "B", "C"]
c_simple2 = CredibilityMatrix(simple2)
s_simple2 = Score()

r_simple2 = CrispOutranking(c_simple2, s_simple2)
r_simple2.solve_complete()

o_simple2 = r_simple2.get_outranking("outranking")

print(o_simple2)

# t_simple2 = CrispTable(simple2, o_simple2, l_simple2)
# t_simple2.draw()
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# XD
# [[-1  0  1]
#  [ 1 -1  1]
#  [ 1  1 -1]]
# [['' '' '']
#  ['' '' '']
#  ['' '' '']]
# [['w' '#FF0000' '#00FF00']
#  ['#00FF00' 'w' '#00FF00']
#  ['#00FF00' '#00FF00' 'w']]

# %%
simple2 = np.array([[1,1,0],[0,1,0],[0,0,0]], dtype=np.int32)
l_simple2 = ["A", "B", "C"]
c_simple2 = CredibilityMatrix(simple2)
s_simple2 = Score()

r_simple2 = CrispOutranking(c_simple2, s_simple2)
r_simple2.solve_complete()

o_simple2 = r_simple2.get_outranking("outranking")

print(o_simple2)

# t_simple2 = CrispTable(simple2, o_simple2, l_simple2)
# t_simple2.draw()
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# XD
# [[-1  0  1]
#  [ 1 -1  1]
#  [ 1  1 -1]]
# [['' '' '']
#  ['' '' '']
#  ['' '' '']]
